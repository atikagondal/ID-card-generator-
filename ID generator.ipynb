# %%
# install pillow with pip install Pillow
from PIL import Image,ImageDraw,ImageFont
import qrcode
image = Image.new('RGB', (1000,900), (255,255,255))
draw=ImageDraw.Draw(image)

# %%
#Change Roboto font to any other font like arial
font=ImageFont.truetype('arial.ttf', size=45)
import random 
import os
import datetime
os.system("Title ID card Generated by Atika")

# %%
d_date =datetime.datetime.now()
reg_format_date = d_date.strftime(" %d-%m-%Y\t\t\t\t\t ID CARD Generator \t\t\t\t\t %I:%M:%S %p" )
print ('+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++')
print (reg_format_date)
print ('++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++')

# %%
#Starting position of the message
print('\n\nAll Fields are Mandatory')
print('Avoid any spelling mistakes')
print('Write everything in uppercase letters')
(x,y)=(50,50)

message= input('\n Company name:')
company=message

color='rgb(0,0,0)'
font=ImageFont.truetype('arial.ttf', size=80)
draw.text((x,y),message,fill=color, font=font)

# %%
#Adding an unique id numbers, can take it manually from user

(x,y)=(600, 75)
idnr=random.randint(10000000, 90000000)

message=str('ID'+str(idnr))
color= 'rgb(0,0,0)' 
font= ImageFont.truetype('arial.ttf', size=60)
draw.text((x,y), message, fill=color, font=font)

# %%
#Name 
(x,y)=(50,250)

message=input('Enter your full name:')
name=message 
color = 'rgb(0, 0, 0)' 
font = ImageFont.truetype('arial.ttf', size=45)
draw.text((x, y), message, fill=color, font=font)

# %%
(x, y) = (50, 350)
message = input(' Gender: ')

color = 'rgb(0, 0, 0)' # black color 
draw.text((x, y), message, fill=color, font=font)

(x, y) = (250, 350)
message = input(' Age: ')
color = 'rgb(0, 0, 0)' # black color 
draw.text((x, y), message, fill=color, font=font)

# %%
(x, y) = (50, 650)
message = input('Mobile Number: ')
temp=message
color = 'rgb(0, 0, 0)' 
draw.text((x, y), message, fill=color, font=font)

# %%
(x, y) = (50, 750)
message = input(' Your Address: ')
color = 'rgb(0, 0, 0)' 
draw.text((x, y), message, fill=color, font=font)

# %%
# save the edited image
 
image.save(str(name)+'.png')



img = qrcode.make(str(company)+str(idno))   # this info. is added in QR code, also add other things
img.save(str(idno)+'.bmp')


til = Image.open(name+'.png')
im = Image.open(str(idno)+'.bmp') #25x25
til.paste(im,(600,350))
til.save(name+'.png')

print(('\n\n\nYour ID Card Successfully created in a PNG file '+name+'.png'))
eval(input('\n\nPress any key to Close program...'))
